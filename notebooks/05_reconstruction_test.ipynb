# %%
import reconstruction_sweep as rs
results = rs.run_sweep()
# Out:
# /home/a6237/github/Bimodal_simulation/neutron_xray_sim/materials.py:158: UserWarning: Missing X-ray data file: /home/a6237/github/Bimodal_simulation/neutron_xray_sim/lib/xray_data/N.txt
# Download the NIST XCOM export for element 'N' and save it as lib/xray_data/N.txt
# Element 'N' will be unavailable until the file is added.
#   XRAY_MASS_ATTEN = build_xray_mass_atten()
# /home/a6237/github/Bimodal_simulation/neutron_xray_sim/materials.py:158: UserWarning: Missing X-ray data file: /home/a6237/github/Bimodal_simulation/neutron_xray_sim/lib/xray_data/Mg.txt
# Download the NIST XCOM export for element 'Mg' and save it as lib/xray_data/Mg.txt
# Element 'Mg' will be unavailable until the file is added.
#   XRAY_MASS_ATTEN = build_xray_mass_atten()
# /home/a6237/github/Bimodal_simulation/neutron_xray_sim/materials.py:158: UserWarning: Missing X-ray data file: /home/a6237/github/Bimodal_simulation/neutron_xray_sim/lib/xray_data/Al.txt
# ...
